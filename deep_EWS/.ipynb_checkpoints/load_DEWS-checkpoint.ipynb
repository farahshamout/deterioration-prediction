# %%
from keras import backend as K
import sys
sys.path.append('../deep_EWS/models/')
sys.path.append('../deep_EWS/scripts/')

import warnings
warnings.filterwarnings('ignore')

from DEWS_model import *

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
m=dews(7,12)
m.load_weights('models/DEWS_model.h5')
m.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_13 (InputLayer)           (None, 12, 1)        0
# __________________________________________________________________________________________________
# input_14 (InputLayer)           (None, 12, 1)        0
# __________________________________________________________________________________________________
# input_15 (InputLayer)           (None, 12, 1)        0
# __________________________________________________________________________________________________
# input_16 (InputLayer)           (None, 12, 1)        0
# __________________________________________________________________________________________________
# input_17 (InputLayer)           (None, 12, 1)        0
# __________________________________________________________________________________________________
# ...
